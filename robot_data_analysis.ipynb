# %% [markdown]
# # Test1 & 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import rbarm_metric as rm

working_path = os.getcwd()
dataset_path = os.path.join(working_path,"Dataset")

task1_raw_path = os.path.join(dataset_path,"Task1","RawData")


dir_list = os.listdir(task1_raw_path)

df_test1 = pd.read_csv(os.path.join(task1_raw_path,dir_list[0]),skiprows=[i for i in range(10)])
df_test2 = pd.read_csv(os.path.join(task1_raw_path,dir_list[1]),skiprows=[i for i in range(10)])



for i in range(1,14,1):
    plt.plot(df_test1.iloc[:,i].values)
    plt.plot(df_test2.iloc[:,i].values)
    plt.title(df_test1.columns[i],fontsize=20)
    #print(df.columns[i])
    plt.show()
    
    



rm.poseError()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_408/1160589194.py in <module>
#      28
#      29
# ---> 30 rm.poseError()
#
# TypeError: poseError() missing 2 required positional arguments: 'meanSim' and 'meanGroundtruth'

# %%
from numpy.random import randint

def generate_real_samples(dataset, n_samples):
    # split into images and labels
    
    # choose random instances
    ix = randint(0, len(dataset), n_samples)
    print(ix)
    # select images and labels
    sele_data = []
    for i in ix:
        sele_data.append( dataset[i])
   
    return sele_data

dataX = generate_real_samples(dataX,1000)
print(len(dataX))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os,glob
import rbarm_metric as rm


working_path = os.getcwd()
dataset_path = os.path.join(working_path,"Dataset")
TASK = "Task2"

Task_mean10Hz_path = os.path.join(dataset_path,TASK,TASK+"_mean10Hz.csv")
Task_test_1_path = os.path.join(dataset_path,TASK,"RawData")



Task_mean10Hz = pd.read_csv(Task_mean10Hz_path,skiprows=[i for i in range(10)])

Error_list = []
for test_csv in glob.glob(os.path.join(Task_test_1_path,"*.csv")):
    
    #print()
    Task_test = pd.read_csv(test_csv,skiprows=[i for i in range(10)],index_col='TimeStamp')
    EuclideanError = rm.euclideanError(Task_mean10Hz.values,Task_test.values)
    
    RotationError = rm.rotationError(Task_mean10Hz.values,Task_test.values)
    PoseError = rm.poseError(Task_mean10Hz.values,Task_test.values)
    Error_list.append([EuclideanError,RotationError,PoseError])
    
    
    #print("euclideanError",rm.euclideanError(Task1_mean10Hz.values,Task1_test.values))
    #print("rotationError",rm.rotationError(Task1_mean10Hz.values,Task1_test.values))
    #print("poseError",rm.poseError(Task1_mean10Hz.values,Task1_test.values))


#print(Error_list)
Error_df = pd.DataFrame(Error_list,columns=["EuclideanError","RotationError","PoseError"]).fillna(method="ffill")
plt.plot(Error_df.iloc[:,0])
plt.title("EuclideanError")
plt.show()
plt.plot(Error_df.iloc[:,1])
plt.title("RotationError")
plt.show()
plt.plot(Error_df.iloc[:,2])
plt.title("PoseError")
plt.show()



#print("euclideanError",rm.euclideanError(Task1_mean10Hz.values,Task1_test1.values))
#print("rotationError",rm.rotationError(Task1_mean10Hz.values,Task1_test1.values))
#print("poseError",rm.poseError(Task1_mean10Hz.values,Task1_test1.values))
#print("velocityError",rm.velocityError(Task1_mean10Hz.values,Task1_test1.values))
#print("contactForceError",rm.contactForceError(Task1_mean10Hz.values,Task1_test1.values))

# %%
Task1_test.shape
# Out:
# (4499, 29)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os,glob
import rbarm_metric as rm


meanSim = rm.readSim("E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_1.csv")
meanGroundtruth = rm.readGroundtruth("E:/Server_mantain/robotic_arm/Dataset/Task2/Task2_mean10Hz.csv",meanSim)
RotationError = rm.rotationError(meanGroundtruth,meanSim)
print(RotationError)
# Out:
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_1.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_2.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_3.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_4.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_5.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_6.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_7.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_8.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_9.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_10.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_11.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_12.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_13.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_14.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_15.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_16.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_17.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_18.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_19.csv
# E:/Server_mantain/robotic_arm/Dataset/Task2/RawData/task2_test_20.csv
# 1.4371909677686463

# %% [markdown]
# # Test1 & -1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

working_path = os.getcwd()
dataset_path = os.path.join(working_path,"Dataset")

task1_raw_path = os.path.join(dataset_path,"Task1","RawData")

dir_list = os.listdir(task1_raw_path)

df_test1 = pd.read_csv(os.path.join(task1_raw_path,dir_list[0]),skiprows=[i for i in range(10)])
df_test2 = pd.read_csv(os.path.join(task1_raw_path,dir_list[-1]),skiprows=[i for i in range(10)])



for i in range(1,14,1):
    plt.plot(df_test1.iloc[:,i].values)
    plt.plot(df_test2.iloc[:,i].values)
    plt.title(df_test1.columns[i],fontsize=20)
    #print(df.columns[i])
    plt.show()
    
    

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(df_test1.iloc[:,1].values, df_test1.iloc[:,2].values, df_test1.iloc[:,3].values, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(df_test1.iloc[:,1].values, df_test1.iloc[:,2].values, df_test1.iloc[:,3].values, c='red')
ax.scatter(df_test2.iloc[:,1].values, df_test2.iloc[:,2].values, df_test2.iloc[:,3].values, c='blue')
plt.show()

"""
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, c='red')
plt.show()
"""
# Out:
# "\nfig = plt.figure()\nax = fig.add_subplot(111, projection='3d')\nax.plot_trisurf(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, color='white', edgecolors='grey', alpha=0.5)\nax.scatter(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, c='red')\nplt.show()\n"

# %% [markdown]
# # Test1 & mean

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

working_path = os.getcwd()
dataset_path = os.path.join(working_path,"Dataset")

task1_raw_path = os.path.join(dataset_path,"Task1","RawData")
task1_mean_path = os.path.join(dataset_path,"Task1","Task1_mean10Hz.csv")


dir_list = os.listdir(task1_raw_path)

df_test1 = pd.read_csv(os.path.join(task1_raw_path,dir_list[0]),skiprows=[i for i in range(10)])
df_mean = pd.read_csv(task1_mean_path,skiprows=[i for i in range(10)])



for i in range(1,14,1):
    #plt.plot(df_test1.iloc[:,i].values)
    plt.plot(df_mean.iloc[:,i].values)
    plt.title(df_mean.columns[i],fontsize=20)
    #print(df.columns[i])
    plt.show()
    
    

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(df_test1.iloc[:,1].values, df_test1.iloc[:,2].values, df_test1.iloc[:,3].values, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(df_test1.iloc[:,1].values, df_test1.iloc[:,2].values, df_test1.iloc[:,3].values, c='red')
ax.scatter(df_mean.iloc[:,1].values, df_mean.iloc[:,2].values, df_mean.iloc[:,3].values, c='blue')
plt.show()

"""
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, c='red')
plt.show()
"""
# Out:
# "\nfig = plt.figure()\nax = fig.add_subplot(111, projection='3d')\nax.plot_trisurf(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, color='white', edgecolors='grey', alpha=0.5)\nax.scatter(df.iloc[:,5].values, df.iloc[:,6].values, df.iloc[:,7].values, c='red')\nplt.show()\n"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import rbarm_metric as rm

working_path = os.getcwd()
dataset_path = os.path.join(working_path,"Dataset")

task1_raw_path = os.path.join(dataset_path,"Task1","RawData")

dir_list = os.listdir(task1_raw_path)

df_test1 = pd.read_csv(os.path.join(task1_raw_path,dir_list[0]),skiprows=[i for i in range(10)])
#df_test2 = pd.read_csv(os.path.join(task1_raw_path,dir_list[-1]),skiprows=[i for i in range(10)])

d = df_test1.iloc[10,1:5].values
Rotation_Matrix = rm.RfromQuat(d[3],d[0],d[1],d[2])
Euler_angles = rm.EulerfromQuat(d[3],d[0],d[1],d[2])


print("Rotation_Matrix : \n{}".format(Rotation_Matrix))
print("Euler_angles : \n{}".format(Euler_angles))
# Out:
# Rotation_Matrix :
# [[-0.74747759 -1.38342124  0.0880374 ]
#  [ 1.37940415 -0.73628018  0.16117616]
#  [-0.13729199  0.12198052  0.98810383]]
# Euler_angles :
# [  7.0375063    7.89117579 118.45257294]
