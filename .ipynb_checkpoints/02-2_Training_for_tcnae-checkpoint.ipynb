# %% [markdown]
# # Anomly Detection Training tcnae

# %% [markdown]
# ## Util Function

# %% [markdown]
# ### Import Lib

# %%
# Import the libraries
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt  # for 畫圖用
import pandas as pd# load and evaluate a saved model
from numpy import loadtxt
from tensorflow.keras.models import load_model,save_model
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation,Flatten, LSTM, TimeDistributed, RepeatVector,GRU, Input, ConvLSTM2D, Bidirectional,BatchNormalization
from tensorflow.keras import Input
#from tensorflow.keras.layers.normalization import BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,Nadam


from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_squared_error
import math
import json
from IPython.core.pylabtools import figsize

figsize(15, 7)
# Out:
# C:\Users\user\anaconda3\envs\rtx3070\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\anaconda3\envs\rtx3070\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\user\anaconda3\envs\rtx3070\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Utils

# %%
def read_data(path,o_dtname="Datetime",c_dtname = 'datetime',names=None,skiprows=None):
    df = pd.read_csv(path, sep=',', 
                     parse_dates={c_dtname:[o_dtname]}, 
                     infer_datetime_format=True, 
                     low_memory=False, 
                     na_values=['nan','?'], 
                     index_col=c_dtname,
                     names=names,
                    skiprows=skiprows)

    #df = df.reindex(index=df.index[:,:-1])
    print(df.isnull().sum())
    # filling nan with mean in any columns
    #for j in range(df.shape[1]):        
        #df.iloc[:,j]=df.iloc[:,j].fillna(df.iloc[:,j].mean())
        
    #df.iloc[:,4:] = df.iloc[:,4:]*100
    #another sanity check to make sure that there are not more any nan
    #print(df.isnull().sum())
    #print(df.head())
    return df
#draw_trend
def draw_trend(df,groups,bound=200):
    #figsize(15,10) 
    
    anomly_df = df.copy()
    anomly_df[anomly_df>0] = np.nan
    
    i=1
    Values = df.values
    Anomaly = anomly_df.values
    cols = groups
    
    for group in groups:
        plt.subplot(len(cols), 1, i)
        plt.plot(Values[:bound, group],linewidth=3)
        plt.plot(Anomaly[:bound, group],color='red',linewidth=8)
        plt.title(df.columns[group], y=0.80, loc='right')
        #plt.xticks(range(0,4020,20))
        i += 1
    plt.show()
    print('\n')

def draw_trend_resample(df,groups,resample_freq,bound=200):
    #figsize(15,10) 
    i=1
    Values = df.resample(resample_freq).mean().values
    cols = groups
    for group in groups:
        plt.subplot(len(cols), 1, i)
        plt.plot(Values[:bound, group],linewidth=3)
        #plt.xticks(range(0,bound+10,10))
        plt.title(df.columns[group]+' resample-{}'.format(resample_freq), y=0.80, loc='right')
        i += 1
    plt.tight_layout()
    plt.show()
    
    print('\n')
#draw_corr
def show_corr(df,group):
    plt.matshow(df.iloc[:,group].corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
    plt.title('Spearman_original', size=15)
    plt.xticks(range(len(group)),labels=map(str,group))
    plt.yticks(range(len(group)),labels=map(str,group))
    plt.colorbar()
    plt.show()
    
def show_corr_resample(df,group,resample_freq):
    plt.matshow(df.resample(resample_freq).mean().iloc[:,group].corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
    plt.title('Spearman_resample-{}'.format(resample_freq), size=15)
    plt.xticks(range(len(group)),labels=map(str,group))
    plt.yticks(range(len(group)),labels=map(str,group))
    plt.colorbar()
    plt.show()

# %%
from scipy import stats
def gen_dataset(data,x_window_size,y_window_size):
    X_train = []   #預測點的前 60 天的資料
    y_train = []   #預測點
    for i in range(x_window_size, data.shape[0]-y_window_size,y_window_size):
        X_train.append(data.iloc[i-x_window_size:i, :-1].values)
        
        if np.sum(data.iloc[i-x_window_size:i, -1].values) >= 1:
            y_train.append(1)
        else:
            y_train.append(0)

    X_train, y_train = np.array(X_train), np.array(y_train)  # 轉成numpy array的格式，以利輸入 RNN
    
    #X_train = np.reshape(X_train, (X_train.shape[0], x_window_size,data.shape[1] ))

    """if y_window_size == 1:
        y_train = np.reshape(y_train,(y_train.shape[0], y_train.shape[2]))
    else:
        y_train = np.reshape(y_train,(y_train.shape[0],y_window_size,y_train.shape[2]))"""
        
    print("Gen data info:")
    print("X_data_shape:{}".format(X_train.shape))
    print("y_data_shape:{}".format(y_train.shape))
    print("\n")
          
    return X_train,y_train

def data_scaling(data,X_win_size,y_win_size,mode='robust'):
    
    assert mode == 'robust' or mode == 'minmax','Wrong mode name'
    print("Mode:{}\n".format(mode))
    print(data.describe())
    
    #Record training data index
    data_index = data.shape[0]
   
    # Feature Scaling
    from sklearn.preprocessing import MinMaxScaler,RobustScaler
    if mode =='robust':
         #RobustScaler
        scaler = RobustScaler()
        data[list(data.columns)[:-1]] = scaler.fit_transform(data[list(data.columns)[:-1]])     
    elif mode == 'minmax':        
        #MinMaxScaler
        scaler = MinMaxScaler()
        data.iloc[:,:-1] = scaler.fit_transform(data.iloc[:,:-1])     
    
    print(data.describe())
    #generate dataset
    data_X,data_y = gen_dataset(data,X_win_size,y_win_size)
    
    return data_X,data_y,scaler,data,scaler.get_params()

# %% [markdown]
# ## Training Proccess

# %% [markdown]
# ### Read Data

# %% [markdown]
# # Test df

# %% [markdown]
# ## save test data

# %%
test_df.to_csv("test_df.csv")
np.save("X_test.npy",X_test)
np.save("y_test.npy",y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15408/685407389.py in <module>
# ----> 1 test_df.to_csv("test_df.csv")
#       2 np.save("X_test.npy",X_test)
#       3 np.save("y_test.npy",y_test)
#
# NameError: name 'test_df' is not defined

# %% [markdown]
# ### Save Scaler pickle

# %%
from pickle import dump

#dump(scaler, open('5v_scaler.pkl', 'wb'))
dump(scaler, open('6v_minmax_scaler.pkl', 'wb'))

# %% [markdown]
# ## Random Search TCN_AE

# %%
from sklearn.model_selection import train_test_split
import seaborn as sns

X_WIN = 16
Y_WIN = 1
SCALE_MODE = 'minmax'
select_col = ["CPU utilization (%)","Memory used  (%)","C_anomaly_label"]
def anomaly_map(x):
    label = 1 if x >0 else 0
    return label

#data["gender"] = data["gender"].map(gender_map)
df = pd.read_csv("./RUL_data/53.csv")
plt.plot(df["s11"]-47)

# %%
X.shape[0]
# Out:
# 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from pyts.approximation import PiecewiseAggregateApproximation

X = df["s11"].values.reshape(1,-1)-47
window_size = 10
n_timestamps = X.shape[1]
paa = PiecewiseAggregateApproximation(window_size=window_size)
X_paa = paa.transform(X)

# Show the results for the first time series
plt.figure(figsize=(15,7))
plt.plot(X[0], 'o', ms=4, label='Original')
plt.plot(np.arange(window_size // 2,
                   n_timestamps + window_size // 2,
                   window_size), X_paa[0], 'o-', ms=4, label='Trend')
plt.vlines(np.arange(0, n_timestamps, window_size) - 0.5,
           X[0].min(), X[0].max(), color='g', linestyles='--', linewidth=0.5)
plt.legend(loc='best', fontsize=15)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Euclidean Error', fontsize=12)
plt.title('Tool Center Position Euclidean Error(Day)', fontsize=16)
plt.savefig("Tool Center Position Euclidean Error.jpg")
plt.show()

# %%
 from sklearn.preprocessing import MinMaxScaler
    

s11_arr = df['s11'].values.reshape(-1,1)
scaler = MinMaxScaler()
s11_arr = scaler.fit_transform(s11_arr)

def pre_proc(data,X_win_size,y_win_size):
    X_train = []
    y_train = []
    for i in range(X_win_size, data.shape[0]-y_win_size,y_win_size):
            X_train.append(data[i-X_win_size:i, :])
            y_train.append(data[i:i+y_win_size, :])
    
    return np.array(X_train),np.array(y_train)

X_train,y_train = pre_proc(s11_arr,16,1)
print(y_train.shape)
# Out:
# (178, 1, 1)

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import ParameterSampler
from scipy.stats import randint as sp_randint
from scipy.stats import uniform
import traceback,datetime
import numpy as np
import pandas as pd
import os
import importlib
from IPython.display import clear_output
import seaborn as sns
from tcn import TCN, tcn_full_summary

model = Sequential()
model.add(TCN(
            input_shape=(X_train.shape[1], X_train.shape[2]),
            nb_filters=64,
            kernel_size=3,
            nb_stacks=3,
            dilations=[1,2,4,8],
            use_skip_connections=True,
            dropout_rate=0.0,
            use_batch_norm=False,
            use_layer_norm=False,
        ))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=2, shuffle=False)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 5/5 - 4s - loss: 157.4887 - val_loss: 26.2471 - 4s/epoch - 785ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 7.7059 - val_loss: 0.9201 - 192ms/epoch - 38ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 7.7188 - val_loss: 0.3005 - 178ms/epoch - 36ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 5.8561 - val_loss: 6.6782 - 150ms/epoch - 30ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 2.0245 - val_loss: 4.8993 - 151ms/epoch - 30ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.6072 - val_loss: 2.8781 - 158ms/epoch - 32ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.2618 - val_loss: 0.0934 - 148ms/epoch - 30ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.3488 - val_loss: 0.2674 - 147ms/epoch - 29ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.2015 - val_loss: 0.8406 - 134ms/epoch - 27ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0743 - val_loss: 0.0959 - 130ms/epoch - 26ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0787 - val_loss: 0.0296 - 122ms/epoch - 24ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.0700 - val_loss: 0.1243 - 153ms/epoch - 31ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0402 - val_loss: 0.0582 - 131ms/epoch - 26ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0363 - val_loss: 0.0317 - 126ms/epoch - 25ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0343 - val_loss: 0.0433 - 129ms/epoch - 26ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0344 - 146ms/epoch - 29ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0245 - val_loss: 0.0369 - 125ms/epoch - 25ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0209 - val_loss: 0.0303 - 125ms/epoch - 25ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0190 - val_loss: 0.0304 - 124ms/epoch - 25ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0175 - val_loss: 0.0301 - 125ms/epoch - 25ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0160 - val_loss: 0.0305 - 125ms/epoch - 25ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0149 - val_loss: 0.0298 - 126ms/epoch - 25ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0136 - val_loss: 0.0286 - 125ms/epoch - 25ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0129 - val_loss: 0.0289 - 122ms/epoch - 24ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.0115 - val_loss: 0.0277 - 120ms/epoch - 24ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.0111 - val_loss: 0.0285 - 126ms/epoch - 25ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0277 - 121ms/epoch - 24ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0100 - val_loss: 0.0281 - 126ms/epoch - 25ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0093 - val_loss: 0.0276 - 135ms/epoch - 27ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0099 - val_loss: 0.0285 - 126ms/epoch - 25ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.0094 - val_loss: 0.0268 - 126ms/epoch - 25ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.0288 - 130ms/epoch - 26ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.0276 - 123ms/epoch - 25ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0131 - val_loss: 0.0283 - 131ms/epoch - 26ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.0137 - val_loss: 0.0265 - 146ms/epoch - 29ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.0181 - val_loss: 0.0288 - 132ms/epoch - 26ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0208 - val_loss: 0.0284 - 120ms/epoch - 24ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0288 - val_loss: 0.0286 - 128ms/epoch - 26ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0343 - val_loss: 0.0304 - 127ms/epoch - 25ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0474 - val_loss: 0.0325 - 120ms/epoch - 24ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0601 - val_loss: 0.0298 - 127ms/epoch - 25ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.0812 - val_loss: 0.0605 - 123ms/epoch - 25ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0977 - val_loss: 0.0441 - 131ms/epoch - 26ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.1238 - val_loss: 0.1146 - 128ms/epoch - 26ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.1335 - val_loss: 0.0935 - 129ms/epoch - 26ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.1457 - val_loss: 0.1985 - 127ms/epoch - 25ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.1231 - val_loss: 0.1320 - 135ms/epoch - 27ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.1092 - val_loss: 0.2281 - 126ms/epoch - 25ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.0648 - val_loss: 0.1132 - 133ms/epoch - 27ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0444 - val_loss: 0.1382 - 127ms/epoch - 25ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0172 - val_loss: 0.0489 - 131ms/epoch - 26ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0114 - val_loss: 0.0459 - 136ms/epoch - 27ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.0270 - 130ms/epoch - 26ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0241 - 124ms/epoch - 25ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0238 - 128ms/epoch - 26ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0239 - 124ms/epoch - 25ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0247 - 127ms/epoch - 25ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0246 - 129ms/epoch - 26ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0033 - val_loss: 0.0252 - 124ms/epoch - 25ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0030 - val_loss: 0.0251 - 127ms/epoch - 25ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0256 - 127ms/epoch - 25ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0258 - 124ms/epoch - 25ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0262 - 124ms/epoch - 25ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0263 - 124ms/epoch - 25ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0264 - 122ms/epoch - 24ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0264 - 133ms/epoch - 27ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0266 - 125ms/epoch - 25ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0266 - 126ms/epoch - 25ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0267 - 134ms/epoch - 27ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0266 - 137ms/epoch - 27ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0034 - val_loss: 0.0268 - 124ms/epoch - 25ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0269 - 133ms/epoch - 27ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0054 - val_loss: 0.0269 - 122ms/epoch - 24ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.0270 - 141ms/epoch - 28ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0109 - val_loss: 0.0268 - 126ms/epoch - 25ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0160 - val_loss: 0.0266 - 122ms/epoch - 24ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0260 - val_loss: 0.0262 - 122ms/epoch - 24ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0404 - val_loss: 0.0268 - 128ms/epoch - 26ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0668 - val_loss: 0.0285 - 131ms/epoch - 26ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.1032 - val_loss: 0.0273 - 120ms/epoch - 24ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.1678 - val_loss: 0.0445 - 130ms/epoch - 26ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.2431 - val_loss: 0.0550 - 132ms/epoch - 26ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.3439 - val_loss: 0.1752 - 137ms/epoch - 27ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.3687 - val_loss: 0.2330 - 129ms/epoch - 26ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.3668 - val_loss: 0.4048 - 125ms/epoch - 25ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.2855 - val_loss: 0.3078 - 133ms/epoch - 27ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.2068 - val_loss: 0.6659 - 132ms/epoch - 26ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0653 - val_loss: 0.1804 - 122ms/epoch - 24ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0292 - val_loss: 0.1109 - 127ms/epoch - 25ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0202 - val_loss: 0.0283 - 125ms/epoch - 25ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0229 - val_loss: 0.0359 - 117ms/epoch - 23ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0184 - val_loss: 0.0615 - 127ms/epoch - 25ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0105 - val_loss: 0.0378 - 127ms/epoch - 25ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.0302 - 129ms/epoch - 26ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0252 - 137ms/epoch - 27ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0255 - 136ms/epoch - 27ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0256 - 129ms/epoch - 26ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0250 - 123ms/epoch - 25ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0237 - 129ms/epoch - 26ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0234 - 122ms/epoch - 24ms/step

# %%
# make a prediction
yhat = model.predict(X_train)

inv_yhat = scaler.inverse_transform(yhat.reshape(-1,1))

plt.plot(inv_yhat,color = 'red',marker='.', label = 'Predict MEM Used',linewidth=3)
plt.plot(df["s11"][:-16],color = 'blue',marker='.', label = 'Real MEM Used',linewidth=3)
plt.xticks(fontsize=20,rotation=60)
plt.yticks(fontsize=20)
plt.grid()
plt.legend(fontsize='xx-large')
plt.title('Predicted values and actual values on test data',fontsize=20)
plt.show()

# %%
real_arr = df["s11"].values
real_arr.shape
# Out:
# (195,)

# %%
tmp = X_train[-1]
real_arr = df["s11"].values
for i in range(50):
    yhat = model.predict(tmp.reshape(1,16,1))
    inv_yhat = scaler.inverse_transform(yhat.reshape(-1,1))
    #print(inv_yhat)
    res = np.concatenate([tmp[1:,:],yhat.reshape(1,1)],axis=0)
    
    tmp = res
    real_arr = np.concatenate([real_arr,inv_yhat.reshape(1,)],axis=0)
plt.plot(real_arr)
plt.show()

# %%
plt.plot(yhat[:,0].flatten()[:256],color = 'red',marker='.', label = 'Predict MEM Used',linewidth=3)
plt.plot(x[:,0].flatten()[:256],color = 'blue',marker='.', label = 'Real MEM Used',linewidth=3)
plt.xticks(fontsize=20,rotation=60)
plt.yticks(fontsize=20)
plt.grid()
plt.legend(fontsize='xx-large')
#plt.title('Predicted values and actual values on test data',fontsize=20)
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def cal_score(y_real,y_hat,model_name):
    from sklearn.metrics import mean_squared_error
    from sklearn.metrics import mean_absolute_error
    import math

    MAEScore = mean_absolute_error(y_real,y_hat)
    RMSEScore = math.sqrt(mean_squared_error(y_real,y_hat))
    MAPEScore = mean_absolute_percentage_error(y_real,y_hat)
        
    print("Model,MAE,RMSE,MAPE")
    print("{},{},{},{}".format(model_name,round(MAEScore,3),round(RMSEScore,3),round(MAPEScore,3)))
    
    
    return round(MAEScore,3),round(RMSEScore,3),round(MAPEScore,3)

MAE,RMSE,MAPE = cal_score(x,x_hat,"Conv")
MAE,RMSE,MAPE = cal_score(x,x_hat,"TCN")
# Out:
# Conv
# MAE:0.15
# RMSE:0.527
# MAPE:4.775
