# %%
import pandas as pd
import numpy as np
import os

#path
DataSet_path = "E:/Server_mantain/robotic_arm/NIST_Dataset"
raw_data = "ur5testresult_halfspeed_payload4.5lb_1.csv"
header_name_txt = os.path.join(DataSet_path,"header.txt")

#get header
with open(header_name_txt) as f:
    header_list = f.readline().split("\t")
    #header_list[-1] = 
    

#read data
df_raw = pd.read_csv(os.path.join(DataSet_path,raw_data),names=header_list)
df_raw.describe
# Out:
# ROBOT_TARGET_JOINT_POSITIONS (J1)
# <bound method NDFrame.describe of                   ROBOT_TIME ROBOT_TARGET_JOINT_POSITIONS (J1)  \
# 0               ([13867.472]              [-26.880068716264294
# 1                ([13867.48]              [-26.880068716264294
# 2               ([13867.488]              [-26.880068716264294
# 3               ([13867.496]              [-26.880068716264294
# 4      ([13867.503999999999]              [-26.880068716264294
# ...                      ...                               ...
# 10181            ([13948.92]              [-30.409898294214994
# 10182           ([13948.928]              [-30.409898294214994
# 10183           ([13948.936]              [-30.409898294214994
# 10184           ([13948.944]              [-30.409898294214994
# 10185           ([13948.952]              [-30.409898294214994
#
#        ROBOT_TARGET_JOINT_POSITIONS (J2)  ROBOT_TARGET_JOINT_POSITIONS (J3)  \
# 0                             -79.911609                          57.095392
# 1                             -79.911609                          57.095392
# 2                             -79.911609                          57.095392
# 3                             -79.911609                          57.095392
# 4                             -79.911609                          57.095392
# ...                                  ...                                ...
# 10181                         -64.578352                          57.098133
# 10182                         -64.578352                          57.098133
# 10183                         -64.578352                          57.098133
# 10184                         -64.578352                          57.098133
# 10185                         -64.578352                          57.098133
#
#        ROBOT_TARGET_JOINT_POSITIONS (J4)  ROBOT_TARGET_JOINT_POSITIONS (J5)  \
# 0                            -157.771764                        -105.009613
# 1                            -157.771764                        -105.009613
# 2                            -157.771764                        -105.009613
# 3                            -157.771764                        -105.009613
# 4                            -157.771764                        -105.009613
# ...                                  ...                                ...
# 10181                        -168.915742                        -105.007471
# 10182                        -168.915742                        -105.007471
# 10183                        -168.915742                        -105.007471
# 10184                        -168.915742                        -105.007471
# 10185                        -168.915742                        -105.007471
#
#       ROBOT_TARGET_JOINT_POSITIONS (J6) ROBOT_ACTUAL_JOINT_POSITIONS (J1)  \
# 0                   -44.72477900700451]              [-26.881428894723115
# 1                   -44.72477900700451]               [-26.87937983797211
# 2                   -44.72477900700451]               [-26.88006285688911
# 3                   -44.72477900700451]              [-26.881428894723115
# 4                   -44.72477900700451]              [-26.880745875806113
# ...                                 ...                               ...
# 10181               -44.72263187478186]               [-30.40793752547074
# 10182               -44.72263187478186]              [-30.412745978646427
# 10183               -44.72263187478186]               [-30.40998658222174
# 10184               -44.72263187478186]               [-30.40793752547074
# 10185               -44.72263187478186]               [-30.40793752547074
#
#        ROBOT_ACTUAL_JOINT_POSITIONS (J2)  ROBOT_ACTUAL_JOINT_POSITIONS (J3)  \
# 0                             -79.910908                          57.093360
# 1                             -79.909542                          57.091284
# 2                             -79.908859                          57.091284
# 3                             -79.910908                          57.091967
# 4                             -79.910225                          57.093360
# ...                                  ...                                ...
# 10181                         -64.575850                          57.098851
# 10182                         -64.576533                          57.100873
# 10183                         -64.575850                          57.099507
# 10184                         -64.574484                          57.098851
# 10185                         -64.577216                          57.095409
#
#        ...  ROBOT_TCP_FORCE (z)  ROBOT_TCP_FORCE (rx) ROBOT_TCP_FORCE (ry)  \
# 0      ...           -14.279688              0.917702             0.978188
# 1      ...           -13.364465              0.840332             0.869831
# 2      ...           -13.174046              0.688056             0.940980
# 3      ...           -13.940458              0.947240             1.076046
# 4      ...           -13.733321              0.879644             0.983616
# ...    ...                  ...                   ...                  ...
# 10181  ...             1.594702              1.372040             1.489852
# 10182  ...             2.682507              1.041598             1.296605
# 10183  ...             1.319381              1.408849             1.487707
# 10184  ...             1.635770              1.232331             1.588208
# 10185  ...             1.576562              1.462212             1.372762
#
#          ROBOT_TCP_FORCE (rz)  ROBOT_JOINT_TEMP (J1)  ROBOT_JOINT_TEMP (J2)  \
# 0       0.022847212757561457]     [27.37999153137207              28.789991
# 1        0.04245950647598208]     [27.37999153137207              28.789991
# 2        0.01252456524221364]     [27.37999153137207              28.789991
# 3        0.05376055343953829]     [27.37999153137207              28.789991
# 4        -0.2324520875317143]     [27.37999153137207              28.789991
# ...                       ...                    ...                    ...
# 10181     -5.470089403011304]    [27.509990692138672              28.919991
# 10182     -5.593352753765461]    [27.509990692138672              28.919991
# 10183     -5.683520574041066]    [27.509990692138672              28.919991
# 10184     -5.587437738657436]    [27.509990692138672              28.919991
# 10185     -5.483381427738428]    [27.509990692138672              28.919991
#
#        ROBOT_JOINT_TEMP (J3)  ROBOT_JOINT_TEMP (J4) ROBOT_JOINT_TEMP (J5)  \
# 0                  28.929893              33.399982             33.393852
# 1                  28.929893              33.399982             33.394466
# 2                  28.929893              33.399982             33.394466
# 3                  28.929905              33.399982             33.394466
# 4                  28.929905              33.399982             33.394466
# ...                      ...                    ...                   ...
# 10181              29.049992              33.689983             33.649982
# 10182              29.049992              33.689983             33.649982
# 10183              29.049992              33.689983             33.649982
# 10184              29.049992              33.689983             33.649982
# 10185              29.049992              33.689983             33.649982
#
#       ROBOT_JOINT_TEMP (J6)\n
# 0         34.92998123168945])
# 1         34.92998123168945])
# 2         34.92998123168945])
# 3         34.92998123168945])
# 4         34.92998123168945])
# ...                       ...
# 10181     35.31191635131836])
# 10182     35.31191635131836])
# 10183     35.31191635131836])
# 10184     35.31191635131836])
# 10185     35.31272506713867])
#
# [10186 rows x 73 columns]>
